# %% [markdown]
# 1. Data Loading

# %%
import pandas as pd


df = pd.read_csv('hardwareStore.csv')
df
# Out:
#       CATEGORY_ID CATEGORY_NAME  PRODUCT_ID               PRODUCT_NAME  \
# 0               1           CPU           8      Intel Xeon E5-1650 V4
# 1               1           CPU           8      Intel Xeon E5-1650 V4
# 2               1           CPU           8      Intel Xeon E5-1650 V4
# 3               1           CPU           8      Intel Xeon E5-1650 V4
# 4               1           CPU           8      Intel Xeon E5-1650 V4
# ...           ...           ...         ...                        ...
# 1107            5       Storage         273  Western Digital WD101KRYZ
# 1108            5       Storage         273  Western Digital WD101KRYZ
# 1109            5       Storage         273  Western Digital WD101KRYZ
# 1110            5       Storage         273  Western Digital WD101KRYZ
# 1111            5       Storage         273  Western Digital WD101KRYZ
#
#                                             DESCRIPTION  \
# 0                         Speed:3.6GHz,Cores:6,TDP:140W
# ...

# %% [markdown]
# 2. Initial Data Analysis

# %%
mean_value = df.mean()
median_value = df.median()
std_deviation = df.std()

print("Mean:")
print(mean_value)

print("Median:")
print(median_value)

print("Standard Deviation:")
print(std_deviation)
# Out:
# Mean:
# CATEGORY_ID        3.203237
# PRODUCT_ID       139.579137
# STANDARD_COST    765.520405
# LIST_PRICE       950.993327
# REGION_ID          2.469424
# LOCATION_ID       10.971223
# WAREHOUSE_ID       5.548561
# QUANTITY         107.474820
# dtype: float64
# Median:
# CATEGORY_ID        4.00
# PRODUCT_ID       133.00
# STANDARD_COST    582.02
# LIST_PRICE       744.98
# REGION_ID          2.00
# LOCATION_ID       11.00
# WAREHOUSE_ID       6.00
# QUANTITY          98.00
# dtype: float64
# Standard Deviation:
# CATEGORY_ID        1.637782
# PRODUCT_ID        84.840057
# STANDARD_COST    794.252142
# LIST_PRICE       991.070482
# REGION_ID          0.499289
# LOCATION_ID        4.662225
# WAREHOUSE_ID       2.416821
# QUANTITY          68.008413
# dtype: float64
# ...

# %%
unique = df['CATEGORY_NAME'].unique()
uniquee = df['PRODUCT_NAME'].unique()
uniqueeee = df['ADDRESS'].unique()

print("Unique categories and their counts:")
print(unique)
print(uniquee)
print(uniqueeee)
# Out:
# Unique categories and their counts:
# ['CPU' 'Video Card' 'Mother Board' 'Storage']
# ['Intel Xeon E5-1650 V4' 'Intel Xeon E5-1650 V4 (OEM/Tray)'
#  'Intel Xeon E5-2630 V3 (OEM/Tray)' 'Intel Xeon E5-1650 V3'
#  'Intel Core i7-5930K' 'Intel Xeon E5-2699 V3 (OEM/Tray)'
#  'Intel Xeon E5-2697 V4' 'Intel Xeon E5-2695 V3 (OEM/Tray)'
#  'Intel Xeon E5-2697 V2' 'Intel Xeon E5-2695 V2' 'Intel Xeon E5-2687W V3'
#  'Intel Xeon E5-2687W V4' 'Intel Xeon E5-2690 V4' 'Intel Xeon E5-2690 V3'
#  'Intel Xeon E5-2683 V4' 'Intel Xeon E5-2699 V4 (OEM/Tray)'
#  'Intel Xeon E5-1680 V3 (OEM/Tray)' 'Intel Xeon E5-2643 V4 (OEM/Tray)'
#  'Intel Core i7-6950X (OEM/Tray)' 'Intel Xeon E5-2680 V4'
#  'Intel Xeon E5-2680 V3 (OEM/Tray)' 'Intel Xeon E5-2660 V4'
#  'Intel Xeon E5-2650' 'Intel Core i9-7900X'
#  'Intel Xeon E5-1660 V3 (OEM/Tray)' 'Intel Core i7-5960X'
#  'Intel Xeon E5-2640 V4' 'Intel Xeon E5-2640 V3'
#  'Intel Core 2 Extreme QX9775' 'AMD Opteron 6378'
# ...

# %% [markdown]
# 3. Category Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sne

summary_stats = df[['CATEGORY_NAME','PRODUCT_NAME']].describe()

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sne.histplot(df['CATEGORY_NAME'],bins=15,kde=True)
plt.title('Distribution of Products Across Categories')
# Out:
# Text(0.5, 1.0, 'Distribution of Products Across Categories')

# %%
correlation_matrix = df[['CATEGORY_ID','PRODUCT_ID']].corr()

plt.figure(figsize=(8,6))
sne.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# 4. Cost and Price Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sne

summary_stats = df[['STANDARD_COST','LIST_PRICE']].describe()

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sne.histplot(df['STANDARD_COST'],bins=15,kde=True)
plt.title('AVERAGE STANDARD COST AND AVERAGE LIST PRICE')
# Out:
# Text(0.5, 1.0, 'AVERAGE STANDARD COST AND AVERAGE LIST PRICE')

# %%
max_value = df['STANDARD_COST'].max()
max_valuee = df['LIST_PRICE'].max()

print(max_value)
print(max_valuee)
# Out:
# 7123.66
# 8867.99

# %% [markdown]
# 5. Location Analysis

# %%
summary_stats = df[['STATE','PRODUCT_ID']].describe()

plt.figure(figsize=(30,5))

plt.subplot(1,2,1)
sne.histplot(df['STATE'],bins=15,kde=True)
plt.title('CITY WITH THE HIGHEST QUANTITY OF PRODUCTS')
# Out:
# Text(0.5, 1.0, 'CITY WITH THE HIGHEST QUANTITY OF PRODUCTS')

# %% [markdown]
# 6. INSIGHTS AND REPORTING

# %%
report = f"""
***Explanatory Data Analysis Report***
***Summary Statistics***
{mean_value}
{median_value}
{std_deviation}
{unique}
{uniquee}
{uniqueee}
{max_value}
{max_valuee}
"""

print(report)
# Out:
# ***Explanatory Data Analysis Report***
# ***Summary Statistics***
# CATEGORY_ID        3.203237
# PRODUCT_ID       139.579137
# STANDARD_COST    765.520405
# LIST_PRICE       950.993327
# REGION_ID          2.469424
# LOCATION_ID       10.971223
# WAREHOUSE_ID       5.548561
# QUANTITY         107.474820
# dtype: float64
# CATEGORY_ID        4.00
# PRODUCT_ID       133.00
# STANDARD_COST    582.02
# LIST_PRICE       744.98
# REGION_ID          2.00
# LOCATION_ID       11.00
# WAREHOUSE_ID       6.00
# QUANTITY          98.00
# dtype: float64
# CATEGORY_ID        1.637782
# PRODUCT_ID        84.840057
# STANDARD_COST    794.252142
# LIST_PRICE       991.070482
# REGION_ID          0.499289
# LOCATION_ID        4.662225
# WAREHOUSE_ID       2.416821
# QUANTITY          68.008413
# dtype: float64
# ['CPU' 'Video Card' 'Mother Board' 'Storage']
# ['Intel Xeon E5-1650 V4' 'Intel Xeon E5-1650 V4 (OEM/Tray)'
#  'Intel Xeon E5-2630 V3 (OEM/Tray)' 'Intel Xeon E5-1650 V3'
# ...
