# %% [markdown]
# 1. Creating Dataset

# %%
import pandas as pd

data = {
    'student_Id': range(1,21),
    'gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female','Male','Female','Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female','Male','Female'],
    'test_date': pd.date_range(start='2024-02-21',periods=20),
    'study_hours': [1,2,5,7,7,8,4,5,8,7,9,1,4,5,6,3,2,8,9,7],
    'test_score': [74,75,85,95,96,92,81,83,81,84,74,75,85,95,96,92,81,83,81,84],
    'attendance': ['Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent','Present','Absent']
}

df = pd.DataFrame(data)

df.to_csv('student_performsnce.csv',index=False)

# %% [markdown]
# 2. Data Loading and Initial Examination

# %%
df = pd.read_csv('student_performsnce.csv')

print(df.head(8))

print(df.isnull().sum())
# Out:
#    student_Id  gender   test_date  study_hours  test_score attendance
# 0           1    Male  2024-02-21            1          74    Present
# 1           2  Female  2024-02-22            2          75     Absent
# 2           3    Male  2024-02-23            5          85    Present
# 3           4  Female  2024-02-24            7          95     Absent
# 4           5    Male  2024-02-25            7          96    Present
# 5           6  Female  2024-02-26            8          92     Absent
# 6           7    Male  2024-02-27            4          81    Present
# 7           8  Female  2024-02-28            5          83     Absent
# student_Id     0
# gender         0
# test_date      0
# study_hours    0
# test_score     0
# attendance     0
# dtype: int64

# %% [markdown]
# 3. Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sne

summary_stats = df[['test_score','study_hours']].describe()

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sne.histplot(df['test_score'],bins=15,kde=True)
plt.title('Distribution of Test Score')

plt.subplot(1,2,2)
sne.histplot(df['study_hours'],bins=15,kde=True)
plt.title('Distribution of Study Hours')
# Out:
# Text(0.5, 1.0, 'Distribution of Study Hours')

# %%
plt.figure(figsize=(8,6))
sne.scatterplot(data=df,x='study_hours',y='test_score')
plt.title('Scatter Plot: Study Hours VS Test Score')
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Study Hours VS Test Score')

# %% [markdown]
# 4. Data Visualization

# %%
plt.figure(figsize=(6,4))
sne.countplot(data=df,x='gender')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
plt.figure(figsize=(10,6))
sne.lineplot(data=df,x='test_date',y='test_score')
plt.title('Trend in Test Score Over Time')
# Out:
# Text(0.5, 1.0, 'Trend in Test Score Over Time')

# %%
correlation_matrix = df[['study_hours','test_score','attendance']].corr()

plt.figure(figsize=(8,6))
sne.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# <ipython-input-21-86c5c4b5d088>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[['study_hours','test_score','attendance']].corr()
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# 5. Insight Reports

# %%
report = f"""
***Explanatory Data Analysis Report***
***Summary Statistics***
{summary_stats}
"""

print(report)
# Out:
# ***Explanatory Data Analysis Report***
# ***Summary Statistics***
#        test_score  study_hours
# count   20.000000    20.000000
# mean    84.600000     5.400000
# std      7.443825     2.603641
# min     74.000000     1.000000
# 25%     81.000000     3.750000
# 50%     83.500000     5.500000
# 75%     92.000000     7.250000
# max     96.000000     9.000000
